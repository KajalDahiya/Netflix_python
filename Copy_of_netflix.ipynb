# %%
import pandas as pd
data=pd.read_csv("netflix.csv")

# %%
data
# Out:
#        show_id     type                                        title  \
# 0     81145628    Movie      Norm of the North: King Sized Adventure
# 1     80117401    Movie                   Jandino: Whatever it Takes
# 2     70234439  TV Show                           Transformers Prime
# 3     80058654  TV Show             Transformers: Robots in Disguise
# 4     80125979    Movie                                 #realityhigh
# ...        ...      ...                                          ...
# 6229  80000063  TV Show                                 Red vs. Blue
# 6230  70286564  TV Show                                        Maron
# 6231  80116008    Movie       Little Baby Bum: Nursery Rhyme Friends
# 6232  70281022  TV Show  A Young Doctor's Notebook and Other Stories
# 6233  70153404  TV Show                                      Friends
#
#                       director  \
# 0     Richard Finn, Tim Maltby
# 1                          NaN
# 2                          NaN
# ...

# %%
data.head()
# Out:
#     show_id     type                                    title  \
# 0  81145628    Movie  Norm of the North: King Sized Adventure
# 1  80117401    Movie               Jandino: Whatever it Takes
# 2  70234439  TV Show                       Transformers Prime
# 3  80058654  TV Show         Transformers: Robots in Disguise
# 4  80125979    Movie                             #realityhigh
#
#                    director  \
# 0  Richard Finn, Tim Maltby
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4          Fernando Lebrija
#
#                                                 cast  \
# 0  Alan Marriott, Andrew Toth, Brian Dobson, Cole...
# 1                                   Jandino Asporaat
# 2  Peter Cullen, Sumalee Montano, Frank Welker, J...
# 3  Will Friedle, Darren Criss, Constance Zimmer, ...
# 4  Nesta Cooper, Kate Walsh, John Michael Higgins...
#
#                                     country         date_added  release_year  \
# ...

# %%
data.tail()
# Out:
#        show_id     type                                        title director  \
# 6229  80000063  TV Show                                 Red vs. Blue      NaN
# 6230  70286564  TV Show                                        Maron      NaN
# 6231  80116008    Movie       Little Baby Bum: Nursery Rhyme Friends      NaN
# 6232  70281022  TV Show  A Young Doctor's Notebook and Other Stories      NaN
# 6233  70153404  TV Show                                      Friends      NaN
#
#                                                    cast         country  \
# 6229  Burnie Burns, Jason Saldaña, Gustavo Sorola, G...   United States
# 6230  Marc Maron, Judd Hirsch, Josh Brener, Nora Zeh...   United States
# 6231                                                NaN             NaN
# 6232  Daniel Radcliffe, Jon Hamm, Adam Godley, Chris...  United Kingdom
# 6233  Jennifer Aniston, Courteney Cox, Lisa Kudrow, ...   United States
#
#      date_added  release_year rating    duration  \
# ...

# %%
data.shape
# Out:
# (6234, 12)

# %%
data.size
# Out:
# 74808

# %%
data.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %%
data.dtypes
# Out:
# show_id          int64
# type            object
# title           object
# director        object
# cast            object
# country         object
# date_added      object
# release_year     int64
# rating          object
# duration        object
# listed_in       object
# description     object
# dtype: object

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6234 entries, 0 to 6233
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       6234 non-null   int64
#  1   type          6234 non-null   object
#  2   title         6234 non-null   object
#  3   director      4265 non-null   object
#  4   cast          5664 non-null   object
#  5   country       5758 non-null   object
#  6   date_added    6223 non-null   object
#  7   release_year  6234 non-null   int64
#  8   rating        6224 non-null   object
#  9   duration      6234 non-null   object
#  10  listed_in     6234 non-null   object
#  11  description   6234 non-null   object
# dtypes: int64(2), object(10)
# memory usage: 584.6+ KB

# %%
data.head()
# Out:
#     show_id     type                                    title  \
# 0  81145628    Movie  Norm of the North: King Sized Adventure
# 1  80117401    Movie               Jandino: Whatever it Takes
# 2  70234439  TV Show                       Transformers Prime
# 3  80058654  TV Show         Transformers: Robots in Disguise
# 4  80125979    Movie                             #realityhigh
#
#                    director  \
# 0  Richard Finn, Tim Maltby
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4          Fernando Lebrija
#
#                                                 cast  \
# 0  Alan Marriott, Andrew Toth, Brian Dobson, Cole...
# 1                                   Jandino Asporaat
# 2  Peter Cullen, Sumalee Montano, Frank Welker, J...
# 3  Will Friedle, Darren Criss, Constance Zimmer, ...
# 4  Nesta Cooper, Kate Walsh, John Michael Higgins...
#
#                                     country         date_added  release_year  \
# ...

# %%
data.shape
# Out:
# (6234, 12)

# %%
data[data.duplicated()]
# Out:
# Empty DataFrame
# Columns: [show_id, type, title, director, cast, country, date_added, release_year, rating, duration, listed_in, description]
# Index: []

# %%
data.drop_duplicates(inplace=True)

# %%
data.shape
# Out:
# (6234, 12)

# %%
data.head()
# Out:
#     show_id     type                                    title  \
# 0  81145628    Movie  Norm of the North: King Sized Adventure
# 1  80117401    Movie               Jandino: Whatever it Takes
# 2  70234439  TV Show                       Transformers Prime
# 3  80058654  TV Show         Transformers: Robots in Disguise
# 4  80125979    Movie                             #realityhigh
#
#                    director  \
# 0  Richard Finn, Tim Maltby
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4          Fernando Lebrija
#
#                                                 cast  \
# 0  Alan Marriott, Andrew Toth, Brian Dobson, Cole...
# 1                                   Jandino Asporaat
# 2  Peter Cullen, Sumalee Montano, Frank Welker, J...
# 3  Will Friedle, Darren Criss, Constance Zimmer, ...
# 4  Nesta Cooper, Kate Walsh, John Michael Higgins...
#
#                                     country         date_added  release_year  \
# ...

# %%
data.isnull()
# Out:
#       show_id   type  title  director   cast  country  date_added  \
# 0       False  False  False     False  False    False       False
# 1       False  False  False      True  False    False       False
# 2       False  False  False      True  False    False       False
# 3       False  False  False      True  False    False       False
# 4       False  False  False     False  False    False       False
# ...       ...    ...    ...       ...    ...      ...         ...
# 6229    False  False  False      True  False    False        True
# 6230    False  False  False      True  False    False        True
# 6231    False  False  False      True   True     True        True
# 6232    False  False  False      True  False    False        True
# 6233    False  False  False      True  False    False        True
#
#       release_year  rating  duration  listed_in  description
# 0            False   False     False      False        False
# ...

# %%
data.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        1969
# cast             570
# country          476
# date_added        11
# release_year       0
# rating            10
# duration           0
# listed_in          0
# description        0
# dtype: int64

# %%
import seaborn as sns

# %%
sns.heatmap(data.isnull())
# Out:
# <Axes: >

# %%
data.head()
# Out:
#     show_id     type                                    title  \
# 0  81145628    Movie  Norm of the North: King Sized Adventure
# 1  80117401    Movie               Jandino: Whatever it Takes
# 2  70234439  TV Show                       Transformers Prime
# 3  80058654  TV Show         Transformers: Robots in Disguise
# 4  80125979    Movie                             #realityhigh
#
#                    director  \
# 0  Richard Finn, Tim Maltby
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4          Fernando Lebrija
#
#                                                 cast  \
# 0  Alan Marriott, Andrew Toth, Brian Dobson, Cole...
# 1                                   Jandino Asporaat
# 2  Peter Cullen, Sumalee Montano, Frank Welker, J...
# 3  Will Friedle, Darren Criss, Constance Zimmer, ...
# 4  Nesta Cooper, Kate Walsh, John Michael Higgins...
#
#                                     country         date_added  release_year  \
# ...

# %%
data[data['title'].isin(['House of Cards'])]
# Out:
#        show_id     type           title director  \
# 5741  70178217  TV Show  House of Cards      NaN
#
#                                                    cast        country  \
# 5741  Kevin Spacey, Robin Wright, Kate Mara, Corey S...  United States
#
#              date_added  release_year rating   duration  \
# 5741   November 2, 2018          2018  TV-MA  6 Seasons
#
#                     listed_in  \
# 5741  TV Dramas, TV Thrillers
#
#                                             description
# 5741  A ruthless politician will stop at nothing to ...

# %%
data[data['title'].str.contains('House of Cards')]
# Out:
#        show_id     type           title director  \
# 5741  70178217  TV Show  House of Cards      NaN
#
#                                                    cast        country  \
# 5741  Kevin Spacey, Robin Wright, Kate Mara, Corey S...  United States
#
#              date_added  release_year rating   duration  \
# 5741   November 2, 2018          2018  TV-MA  6 Seasons
#
#                     listed_in  \
# 5741  TV Dramas, TV Thrillers
#
#                                             description
# 5741  A ruthless politician will stop at nothing to ...

# %%
data.dtypes
# Out:
# show_id          int64
# type            object
# title           object
# director        object
# cast            object
# country         object
# date_added      object
# release_year     int64
# rating          object
# duration        object
# listed_in       object
# description     object
# dtype: object

# %%
data['Date_N'] = pd.to_datetime(data['date_added'])

# %%
data.head()
# Out:
#     show_id     type                                    title  \
# 0  81145628    Movie  Norm of the North: King Sized Adventure
# 1  80117401    Movie               Jandino: Whatever it Takes
# 2  70234439  TV Show                       Transformers Prime
# 3  80058654  TV Show         Transformers: Robots in Disguise
# 4  80125979    Movie                             #realityhigh
#
#                    director  \
# 0  Richard Finn, Tim Maltby
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4          Fernando Lebrija
#
#                                                 cast  \
# 0  Alan Marriott, Andrew Toth, Brian Dobson, Cole...
# 1                                   Jandino Asporaat
# 2  Peter Cullen, Sumalee Montano, Frank Welker, J...
# 3  Will Friedle, Darren Criss, Constance Zimmer, ...
# 4  Nesta Cooper, Kate Walsh, John Michael Higgins...
#
#                                     country         date_added  release_year  \
# ...

# %%
data['Date_N'].dt.year.value_counts() #it counts the occurrence of all individual years in date column
# Out:
# 2019.0    2349
# 2018.0    1782
# 2017.0    1300
# 2016.0     456
# 2020.0     184
# 2015.0      90
# 2014.0      25
# 2011.0      13
# 2013.0      12
# 2012.0       7
# 2009.0       2
# 2008.0       2
# 2010.0       1
# Name: Date_N, dtype: int64

# %%
data['Date_N'].dt.year.value_counts().plot(kind="bar")
# Out:
# <Axes: >

# %%
data.head(2)
# Out:
#     show_id   type                                    title  \
# 0  81145628  Movie  Norm of the North: King Sized Adventure
# 1  80117401  Movie               Jandino: Whatever it Takes
#
#                    director  \
# 0  Richard Finn, Tim Maltby
# 1                       NaN
#
#                                                 cast  \
# 0  Alan Marriott, Andrew Toth, Brian Dobson, Cole...
# 1                                   Jandino Asporaat
#
#                                     country         date_added  release_year  \
# 0  United States, India, South Korea, China  September 9, 2019          2019
# 1                            United Kingdom  September 9, 2016          2016
#
#   rating duration                           listed_in  \
# 0  TV-PG   90 min  Children & Family Movies, Comedies
# 1  TV-MA   94 min                     Stand-Up Comedy
#
#                                          description     Date_N
# ...

# %%
data.groupby('type').type.count()
# Out:
# type
# Movie      4265
# TV Show    1969
# Name: type, dtype: int64

# %%
data.head(2)
# Out:
#     show_id   type                                    title  \
# 0  81145628  Movie  Norm of the North: King Sized Adventure
# 1  80117401  Movie               Jandino: Whatever it Takes
#
#                    director  \
# 0  Richard Finn, Tim Maltby
# 1                       NaN
#
#                                                 cast  \
# 0  Alan Marriott, Andrew Toth, Brian Dobson, Cole...
# 1                                   Jandino Asporaat
#
#                                     country         date_added  release_year  \
# 0  United States, India, South Korea, China  September 9, 2019          2019
# 1                            United Kingdom  September 9, 2016          2016
#
#   rating duration                           listed_in  \
# 0  TV-PG   90 min  Children & Family Movies, Comedies
# 1  TV-MA   94 min                     Stand-Up Comedy
#
#                                          description     Date_N
# ...

# %%
data['release_year']=data['Date_N'].dt.year

# %%
data.head(2)
# Out:
#     show_id   type                                    title  \
# 0  81145628  Movie  Norm of the North: King Sized Adventure
# 1  80117401  Movie               Jandino: Whatever it Takes
#
#                    director  \
# 0  Richard Finn, Tim Maltby
# 1                       NaN
#
#                                                 cast  \
# 0  Alan Marriott, Andrew Toth, Brian Dobson, Cole...
# 1                                   Jandino Asporaat
#
#                                     country         date_added  release_year  \
# 0  United States, India, South Korea, China  September 9, 2019        2019.0
# 1                            United Kingdom  September 9, 2016        2016.0
#
#   rating duration                           listed_in  \
# 0  TV-PG   90 min  Children & Family Movies, Comedies
# 1  TV-MA   94 min                     Stand-Up Comedy
#
#                                          description     Date_N
# ...

# %%
data[(data['type']=='Movie')&(data['release_year']==2020)]
# Out:
#        show_id   type                                title  \
# 3180  81214114  Movie                        Bulletproof 2
# 3181  81167492  Movie                     Speed Is My Need
# 3194  80173542  Movie                        A Ghost Story
# 3195  80233408  Movie                Live Twice, Love Once
# 3196  70142888  Movie                          The Tourist
# ...        ...    ...                                  ...
# 3597  60001396  Movie                    What Lies Beneath
# 3598  22007250  Movie                       Wild Wild West
# 3599  60020949  Movie  Willy Wonka & the Chocolate Factory
# 3600  60011597  Movie                           Wyatt Earp
# 3601  70100379  Movie                              Yes Man
#
#                               director  \
# 3180                  Don Michael Paul
# 3181                       Mark Sloper
# 3194                      David Lowery
# 3195                      Maria Ripoll
# 3196  Florian Henckel von Donnersmarck
# ...

# %%
data.head(2)
# Out:
#     show_id   type                                    title  \
# 0  81145628  Movie  Norm of the North: King Sized Adventure
# 1  80117401  Movie               Jandino: Whatever it Takes
#
#                    director  \
# 0  Richard Finn, Tim Maltby
# 1                       NaN
#
#                                                 cast  \
# 0  Alan Marriott, Andrew Toth, Brian Dobson, Cole...
# 1                                   Jandino Asporaat
#
#                                     country         date_added  release_year  \
# 0  United States, India, South Korea, China  September 9, 2019        2019.0
# 1                            United Kingdom  September 9, 2016        2016.0
#
#   rating duration                           listed_in  \
# 0  TV-PG   90 min  Children & Family Movies, Comedies
# 1  TV-MA   94 min                     Stand-Up Comedy
#
#                                          description     Date_N
# ...

# %%
#titles of all tv shows that were released in india only
data[(data['type']=='TV Show') & (data['country']=='India')]['title']
# Out:
# 99                                Bard of Blood
# 648                 Mighty Little Bheem: Diwali
# 689               Devlok with Devdutt Pattanaik
# 789                             College Romance
# 793                           Engineering Girls
# 797                                Girls Hostel
# 804                                     Inmates
# 1653                                  Thackeray
# 1762                            Classic Legends
# 1838                Anjaan: Special Crimes Unit
# 1850                   Khan: No. 1 Crime Hunter
# 1998      Th Eena Meena Deeka Chase Comedy Show
# 2090                                Delhi Crime
# 2200                              Khotey Sikkey
# 2210                                 Rishta.com
# 2297              Cricket Fever: Mumbai Indians
# 2333                       Darr Sabko Lagta Hai
# 2359                                   Mahi Way
# 2661                                      Leila
# 2718                  Gabru: Hip Hop Revolution
# ...

# %%
#top 10 directors 
data.head()
# Out:
#     show_id     type                                    title  \
# 0  81145628    Movie  Norm of the North: King Sized Adventure
# 1  80117401    Movie               Jandino: Whatever it Takes
# 2  70234439  TV Show                       Transformers Prime
# 3  80058654  TV Show         Transformers: Robots in Disguise
# 4  80125979    Movie                             #realityhigh
#
#                    director  \
# 0  Richard Finn, Tim Maltby
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4          Fernando Lebrija
#
#                                                 cast  \
# 0  Alan Marriott, Andrew Toth, Brian Dobson, Cole...
# 1                                   Jandino Asporaat
# 2  Peter Cullen, Sumalee Montano, Frank Welker, J...
# 3  Will Friedle, Darren Criss, Constance Zimmer, ...
# 4  Nesta Cooper, Kate Walsh, John Michael Higgins...
#
#                                     country         date_added  release_year  \
# ...

# %%
data['director'].value_counts().head(10)
# Out:
# Raúl Campos, Jan Suter    18
# Marcus Raboy              14
# Jay Karas                 13
# Jay Chapman               12
# Steven Spielberg           9
# Martin Scorsese            9
# Lance Bangs                8
# David Dhawan               8
# Johnnie To                 8
# Shannon Hartman            7
# Name: director, dtype: int64

# %%
#All the records where 'Category is Movie and Type is comedies' or 'country is unnited kingdom'
data.head(2)
# Out:
#     show_id   type                                    title  \
# 0  81145628  Movie  Norm of the North: King Sized Adventure
# 1  80117401  Movie               Jandino: Whatever it Takes
#
#                    director  \
# 0  Richard Finn, Tim Maltby
# 1                       NaN
#
#                                                 cast  \
# 0  Alan Marriott, Andrew Toth, Brian Dobson, Cole...
# 1                                   Jandino Asporaat
#
#                                     country         date_added  release_year  \
# 0  United States, India, South Korea, China  September 9, 2019        2019.0
# 1                            United Kingdom  September 9, 2016        2016.0
#
#   rating duration                           listed_in  \
# 0  TV-PG   90 min  Children & Family Movies, Comedies
# 1  TV-MA   94 min                     Stand-Up Comedy
#
#                                          description     Date_N
# ...

# %%
data[(data['type']=='Movie') & (data['listed_in']=='Stand-Up Comedy') | (data['country']=='United Kingdom')]
# Out:
#        show_id     type                                        title  \
# 1     80117401    Movie                   Jandino: Whatever it Takes
# 7     80164077    Movie           Fabrizio Copano: Solo pienso en mi
# 10    80169755    Movie                  Joaquín Reyes: Una y no más
# 42    80162141    Movie                                    Hard Tide
# 43    80095641    Movie                                 Elstree 1976
# ...        ...      ...                                          ...
# 6180  70250398  TV Show                                        Vexed
# 6186  70258489  TV Show                                        Derek
# 6190  80130911  TV Show                                  Chewing Gum
# 6204  80091341  TV Show                                       Cuckoo
# 6232  70281022  TV Show  A Young Doctor's Notebook and Other Stories
#
#                              director  \
# 1                                 NaN
# 7     Rodrigo Toro, Francisco Schultz
# ...

# %%
#movies/shows where Tom cruise was cast
data.head(2)
# Out:
#     show_id   type                                    title  \
# 0  81145628  Movie  Norm of the North: King Sized Adventure
# 1  80117401  Movie               Jandino: Whatever it Takes
#
#                    director  \
# 0  Richard Finn, Tim Maltby
# 1                       NaN
#
#                                                 cast  \
# 0  Alan Marriott, Andrew Toth, Brian Dobson, Cole...
# 1                                   Jandino Asporaat
#
#                                     country         date_added  release_year  \
# 0  United States, India, South Korea, China  September 9, 2019        2019.0
# 1                            United Kingdom  September 9, 2016        2016.0
#
#   rating duration                           listed_in  \
# 0  TV-PG   90 min  Children & Family Movies, Comedies
# 1  TV-MA   94 min                     Stand-Up Comedy
#
#                                          description     Date_N
# ...

# %%
data[data['cast']=='Tom Cruise']
# Out:
# Empty DataFrame
# Columns: [show_id, type, title, director, cast, country, date_added, release_year, rating, duration, listed_in, description, Date_N]
# Index: []

# %%
data_new=data.dropna()

# %%
data_new.head(2)
# Out:
#     show_id   type                                    title  \
# 0  81145628  Movie  Norm of the North: King Sized Adventure
# 4  80125979  Movie                             #realityhigh
#
#                    director  \
# 0  Richard Finn, Tim Maltby
# 4          Fernando Lebrija
#
#                                                 cast  \
# 0  Alan Marriott, Andrew Toth, Brian Dobson, Cole...
# 4  Nesta Cooper, Kate Walsh, John Michael Higgins...
#
#                                     country         date_added  release_year  \
# 0  United States, India, South Korea, China  September 9, 2019        2019.0
# 4                             United States  September 8, 2017        2017.0
#
#   rating duration                           listed_in  \
# 0  TV-PG   90 min  Children & Family Movies, Comedies
# 4  TV-14   99 min                            Comedies
#
#                                          description     Date_N
# ...

# %%
data_new[data_new['cast'].str.contains('Tom Cruise')]
# Out:
#        show_id   type     title              director  \
# 3071  60029369  Movie  Rain Man        Barry Levinson
# 3538  60000440  Movie  Magnolia  Paul Thomas Anderson
#
#                                                    cast        country  \
# 3071  Dustin Hoffman, Tom Cruise, Valeria Golino, Ge...  United States
# 3538  Jeremy Blackman, Tom Cruise, Melinda Dillon, A...  United States
#
#            date_added  release_year rating duration  \
# 3071     July 1, 2019        2019.0      R  134 min
# 3538  January 1, 2020        2020.0      R  189 min
#
#                        listed_in  \
# 3071      Classic Movies, Dramas
# 3538  Dramas, Independent Movies
#
#                                             description     Date_N
# 3071  A fast-talking yuppie is forced to slow down w... 2019-07-01
# 3538  Through chance, human action, past history and... 2020-01-01

# %%
#different ratings defined by netflix
data.head(2)
# Out:
#     show_id   type                                    title  \
# 0  81145628  Movie  Norm of the North: King Sized Adventure
# 1  80117401  Movie               Jandino: Whatever it Takes
#
#                    director  \
# 0  Richard Finn, Tim Maltby
# 1                       NaN
#
#                                                 cast  \
# 0  Alan Marriott, Andrew Toth, Brian Dobson, Cole...
# 1                                   Jandino Asporaat
#
#                                     country         date_added  release_year  \
# 0  United States, India, South Korea, China  September 9, 2019        2019.0
# 1                            United Kingdom  September 9, 2016        2016.0
#
#   rating duration                           listed_in  \
# 0  TV-PG   90 min  Children & Family Movies, Comedies
# 1  TV-MA   94 min                     Stand-Up Comedy
#
#                                          description     Date_N
# ...

# %%
data['rating'].nunique()
# Out:
# 14

# %%
data['rating'].unique()
# Out:
# array(['TV-PG', 'TV-MA', 'TV-Y7-FV', 'TV-Y7', 'TV-14', 'R', 'TV-Y', 'NR',
#        'PG-13', 'TV-G', 'PG', 'G', nan, 'UR', 'NC-17'], dtype=object)

# %%
#movies which got 'TV-14' rating in canada
data.head(2)
# Out:
#     show_id   type                                    title  \
# 0  81145628  Movie  Norm of the North: King Sized Adventure
# 1  80117401  Movie               Jandino: Whatever it Takes
#
#                    director  \
# 0  Richard Finn, Tim Maltby
# 1                       NaN
#
#                                                 cast  \
# 0  Alan Marriott, Andrew Toth, Brian Dobson, Cole...
# 1                                   Jandino Asporaat
#
#                                     country         date_added  release_year  \
# 0  United States, India, South Korea, China  September 9, 2019        2019.0
# 1                            United Kingdom  September 9, 2016        2016.0
#
#   rating duration                           listed_in  \
# 0  TV-PG   90 min  Children & Family Movies, Comedies
# 1  TV-MA   94 min                     Stand-Up Comedy
#
#                                          description     Date_N
# ...

# %%
data[(data['type']=='Movie') & (data['rating']=='TV-14')]
# Out:
#        show_id   type                          title          director  \
# 4     80125979  Movie                   #realityhigh  Fernando Lebrija
# 20    80060297  Movie              Manhattan Romance       Tom O'Brien
# 36    81113928  Movie          Care of Kancharapalem    Maha Venkatesh
# 37    81052275  Movie          Ee Nagaraniki Emaindi   Tharun Bhascker
# 38    81132437  Movie            Kill Me If You Dare      Şenol Sönmez
# ...        ...    ...                            ...               ...
# 5550  80131414  Movie                Born to Be Free  Gayane Petrosyan
# 5559  80081955  Movie           Five Nights in Maine      Maris Curran
# 5560  80164112  Movie  Joe Cocker: Mad Dog with Soul     John Edginton
# 5562  70302835  Movie                          Killa      Avinash Arun
# 5568  80158479  Movie                      Salaakhen         A. Salaam
#
#                                                    cast  \
# 4     Nesta Cooper, Kate Walsh, John Michael Higgins...
# ...

# %%
data[(data['type']=='Movie') & (data['rating']=='TV-14') & (data['country']=='Canada')]
# Out:
#        show_id   type                                              title  \
# 726   80990869  Movie        Martin Matte: La vie, la mort...eh la la..!
# 1324  80205085  Movie                                  Long Time Running
# 1900  80178720  Movie                                         Kiss & Cry
# 2620  81136963  Movie                               The Wrong Babysitter
# 2631  81123051  Movie                                  3 Seconds Divorce
# 2705  81070008  Movie  Prosecuting Evil: The Extraordinary World of B...
# 3083  81017506  Movie                        The Accountant of Auschwitz
# 3099  80997402  Movie                         Counterfeiting in Suburbia
# 3976  70137744  Movie                     Rush: Beyond the Lighted Stage
# 4332  81029400  Movie                                     At First Light
# 4692  80203787  Movie                                         Sardaar ji
# 4877  80163054  Movie                         Sadie's Last Days on Earth
# ...

# %%
data[(data['type']=='Movie') & (data['rating']=='TV-14') & (data['country']=='Canada')].shape
# Out:
# (13, 13)

# %%
#tv shows which got "R" rating after year 2018
data.head(2)
# Out:
#     show_id   type                                    title  \
# 0  81145628  Movie  Norm of the North: King Sized Adventure
# 1  80117401  Movie               Jandino: Whatever it Takes
#
#                    director  \
# 0  Richard Finn, Tim Maltby
# 1                       NaN
#
#                                                 cast  \
# 0  Alan Marriott, Andrew Toth, Brian Dobson, Cole...
# 1                                   Jandino Asporaat
#
#                                     country         date_added  release_year  \
# 0  United States, India, South Korea, China  September 9, 2019        2019.0
# 1                            United Kingdom  September 9, 2016        2016.0
#
#   rating duration                           listed_in  \
# 0  TV-PG   90 min  Children & Family Movies, Comedies
# 1  TV-MA   94 min                     Stand-Up Comedy
#
#                                          description     Date_N
# ...

# %%
data[(data['type']=='TV Show') & (data['rating']=='R') & (data['release_year']>2018)]
# Out:
#        show_id     type                                title  \
# 5303  80174683  TV Show  The Hateful Eight: Extended Version
#
#                director                                               cast  \
# 5303  Quentin Tarantino  Samuel L. Jackson, Kurt Russell, Jennifer Jaso...
#
#             country      date_added  release_year rating  duration listed_in  \
# 5303  United States  April 25, 2019        2019.0      R  1 Season  TV Shows
#
#                                             description     Date_N
# 5303  Trapped at a stagecoach stop as a storm rages ... 2019-04-25

# %%
#maximum duration of a movie/tv show
data['duration'].unique()
# Out:
# array(['90 min', '94 min', '1 Season', '99 min', '110 min', '60 min',
#        '78 min', '95 min', '58 min', '62 min', '65 min', '61 min',
#        '135 min', '98 min', '96 min', '79 min', '113 min', '80 min',
#        '77 min', '112 min', '106 min', '102 min', '114 min', '125 min',
#        '142 min', '133 min', '100 min', '86 min', '146 min', '10 min',
#        '122 min', '126 min', '116 min', '130 min', '70 min', '128 min',
#        '88 min', '108 min', '93 min', '64 min', '107 min', '92 min',
#        '111 min', '103 min', '40 min', '85 min', '72 min', '45 min',
#        '89 min', '24 min', '127 min', '163 min', '117 min', '42 min',
#        '104 min', '75 min', '82 min', '38 min', '97 min', '81 min',
#        '91 min', '152 min', '87 min', '121 min', '101 min', '119 min',
#        '83 min', '182 min', '124 min', '63 min', '139 min', '171 min',
#        '84 min', '69 min', '76 min', '41 min', '153 min', '141 min',
# ...

# %%
data.duration.dtypes
# Out:
# dtype('O')

# %%
data.head(2)
# Out:
#     show_id   type                                    title  \
# 0  81145628  Movie  Norm of the North: King Sized Adventure
# 1  80117401  Movie               Jandino: Whatever it Takes
#
#                    director  \
# 0  Richard Finn, Tim Maltby
# 1                       NaN
#
#                                                 cast  \
# 0  Alan Marriott, Andrew Toth, Brian Dobson, Cole...
# 1                                   Jandino Asporaat
#
#                                     country         date_added  release_year  \
# 0  United States, India, South Korea, China  September 9, 2019        2019.0
# 1                            United Kingdom  September 9, 2016        2016.0
#
#   rating duration                           listed_in  \
# 0  TV-PG   90 min  Children & Family Movies, Comedies
# 1  TV-MA   94 min                     Stand-Up Comedy
#
#                                          description     Date_N
# ...

# %%
data[['Minutes','Unit']]=data['duration'].str.split(' ',expand=True)

# %%
data.head(2)
# Out:
#     show_id   type                                    title  \
# 0  81145628  Movie  Norm of the North: King Sized Adventure
# 1  80117401  Movie               Jandino: Whatever it Takes
#
#                    director  \
# 0  Richard Finn, Tim Maltby
# 1                       NaN
#
#                                                 cast  \
# 0  Alan Marriott, Andrew Toth, Brian Dobson, Cole...
# 1                                   Jandino Asporaat
#
#                                     country         date_added  release_year  \
# 0  United States, India, South Korea, China  September 9, 2019        2019.0
# 1                            United Kingdom  September 9, 2016        2016.0
#
#   rating duration                           listed_in  \
# 0  TV-PG   90 min  Children & Family Movies, Comedies
# 1  TV-MA   94 min                     Stand-Up Comedy
#
#                                          description     Date_N Minutes Unit
# ...

# %%
data['Minutes'].max()
# Out:
# '99'

# %%
data['Minutes'].min()
# Out:
# '1'

# %%
data['Minutes'].mean()
# Out:
# inf

# %%
#which country has highest no of tv shows
data.head(2)
# Out:
#     show_id   type                                    title  \
# 0  81145628  Movie  Norm of the North: King Sized Adventure
# 1  80117401  Movie               Jandino: Whatever it Takes
#
#                    director  \
# 0  Richard Finn, Tim Maltby
# 1                       NaN
#
#                                                 cast  \
# 0  Alan Marriott, Andrew Toth, Brian Dobson, Cole...
# 1                                   Jandino Asporaat
#
#                                     country         date_added  release_year  \
# 0  United States, India, South Korea, China  September 9, 2019        2019.0
# 1                            United Kingdom  September 9, 2016        2016.0
#
#   rating duration                           listed_in  \
# 0  TV-PG   90 min  Children & Family Movies, Comedies
# 1  TV-MA   94 min                     Stand-Up Comedy
#
#                                          description     Date_N Minutes Unit
# ...

# %%
data_tvshow=data[data['type']=='TV Show']

# %%
data_tvshow.head(2)
# Out:
#     show_id     type                             title director  \
# 2  70234439  TV Show                Transformers Prime      NaN
# 3  80058654  TV Show  Transformers: Robots in Disguise      NaN
#
#                                                 cast        country  \
# 2  Peter Cullen, Sumalee Montano, Frank Welker, J...  United States
# 3  Will Friedle, Darren Criss, Constance Zimmer, ...  United States
#
#           date_added  release_year    rating  duration listed_in  \
# 2  September 8, 2018        2018.0  TV-Y7-FV  1 Season  Kids' TV
# 3  September 8, 2018        2018.0     TV-Y7  1 Season  Kids' TV
#
#                                          description     Date_N Minutes  \
# 2  With the help of three human allies, the Autob... 2018-09-08       1
# 3  When a prison ship crash unleashes hundreds of... 2018-09-08       1
#
#      Unit
# 2  Season
# 3  Season

# %%
data_tvshow.country.value_counts()
# Out:
# United States                                                  550
# United Kingdom                                                 178
# Japan                                                          129
# South Korea                                                    104
# Taiwan                                                          65
#                                                               ...
# United States, Chile                                             1
# France, United States, Canada                                    1
# United States, New Zealand, Japan                                1
# Italy, South Africa, West Germany, Australia, United States      1
# Cyprus, Austria, Thailand                                        1
# Name: country, Length: 154, dtype: int64

# %%
data_tvshow.country.value_counts().head(1)
# Out:
# United States    550
# Name: country, dtype: int64

# %%
#sorting dataset by year
data.sort_values(by='release_year',ascending=False).head(2)
# Out:
#        show_id   type           title       director  \
# 3337  70271454  Movie  The Bling Ring  Sofia Coppola
# 3503   1151721  Movie   Donnie Brasco    Mike Newell
#
#                                                    cast  \
# 3337  Emma Watson, Leslie Mann, Carlos Miranda, Isra...
# 3503  Al Pacino, Johnny Depp, Michael Madsen, Bruno ...
#
#                                                 country        date_added  \
# 3337  United States, United Kingdom, France, Germany...  January 18, 2020
# 3503                                      United States   January 1, 2020
#
#       release_year rating duration                   listed_in  \
# 3337        2020.0      R   91 min  Dramas, Independent Movies
# 3503        2020.0      R  127 min           Dramas, Thrillers
#
#                                             description     Date_N Minutes  \
# 3337  Based on fact, this comic thriller tracks the ... 2020-01-18      91
# ...

# %%
#all instances where category is movie and type is dramas or category is tv show and type is kids tv
data[(data['type']=='Movie') & (data['listed_in']=='Dramas')|(data['type']=='TV Show') & (data['listed_in']=='Kids TV')]
# Out:
#        show_id   type                        title             director  \
# 241   80067522  Movie  First They Killed My Father       Angelina Jolie
# 266   81092328  Movie          American Warfighter      Jerry G. Angelo
# 310   70113003  Movie           My Sister's Keeper      Nick Cassavetes
# 495   80224362  Movie                        Kings  Deniz Gamze Ergüven
# 783   60020891  Movie                         Blow            Ted Demme
# ...        ...    ...                          ...                  ...
# 5351  80015799  Movie                    Good Kill        Andrew Niccol
# 5432  70124562  Movie                  Nowhere Boy   Sam Taylor-Johnson
# 5515  80103383  Movie                 Class of '61       Gregory Hoblit
# 5516  60011619  Movie                          Dad  Gary David Goldberg
# 5555  80115101  Movie                       Deuces           Jamal Hill
#
#                                                    cast  \
# ...
